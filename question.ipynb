# %% [markdown]
# # Python Practice Problems
#
# ## Table of Contents
#
# 1. [String Explosion](#string-explosion)
# 2. [Last 2](#last-2)
# 3. [String Match](#string-match)
# 4. [Sum 13](#sum-13)
# 5. [Sum 67](#sum-67)
# 6. [Round Sum](#round-sum)
# 7. [Make Bricks](#make-bricks)
# 8. [Second Lowest Scores](#second-lowest-scores)
# 9. [Regex: Starts with Digit](#regex-starts-with-digit)
# 10. [Replace Character in String](#replace-character-in-string)

# %% [markdown]
# ---

# %% [markdown]
# ## String Explosion

# %% [markdown]
# **Approach 1**: Loop with string concatenation

# %%
def string_splosion(str):
  final_string = ""
  for n in range(len(str)):
    final_string += str[:n+1]
  return final_string

# %% [markdown]
# **Approach 2**: List comprehension + `join()`

# %%
# strings = ["Code","ab","abc","x"]
string = "Code"

list = [string[:n+1] for n in range(len(string))]
    
"".join(list)

# %% [markdown]
# ---

# %% [markdown]
# ## Last 2
#
# Count how many times the last 2 characters appear in the string (excluding the last 2 themselves).

# %% [markdown]
# **Approach 1**: Using `str.count()` (does not handle overlaps)

# %%
def last2(str):
    substring = str[-2:]
    return str.count(substring)

last2("axxxaaxx")

# %% [markdown]
# **Approach 2**: Regex attempt (also misses overlaps)

# %%
import re

string_ = "axxxaaxx"
substring = string_[-2:]

regex_pattern = f"{re.escape(substring)}"
# len(re.findall(regex_pattern,string_))

for item in re.finditer(regex_pattern,string_):
    print(item)

# Still doesnt find overlaps

# Someway with lookaheads, but this is later stuff.
# for item in re.finditer(f"(?=({re.escape(substring)}))",string_):
#     print(item.start(), item.group(1))

# %% [markdown]
# **Approach 3**: Manual sliding window

# %%
def last2(str):
    substring = str[-2:]
    count=0
    
    for i in range(len(str)-2):
        if(str[i:i+2]==substring):
            count+=1

    return count

last2("axxxaaxx")

# %% [markdown]
# **Approach 4**: List comprehension one-liner

# %%
def last2(str):
    return sum([1 for i in range(len(str)-2) if(str[i:i+2]==str[-2:])])

last2("axxxaaxx")

# %% [markdown]
# ---

# %% [markdown]
# ## String Match
#
# Count the number of positions where the two strings have the same length-2 substring.

# %%
def string_match(a, b):
  len_ = len(a) if len(a) < len(b) else len(b)
  count = 0
  for i in range(len_-1): # was missing -1 here
    print(a[i:i+2],"\t",b[i:i+2])
    if a[i:i+2] == b[i:i+2]:
      count+=1
    
  return count
      
string_match('abc','abc')
# string_match('abc','axc')

# %% [markdown]
# ---

# %% [markdown]
# ## Sum 13
#
# Return the sum of numbers in a list, but skip 13 and the number immediately after it.

# %%
def sum13(nums):
  return sum([num for i, num in enumerate(nums) if (num!=13 and (i == 0 or nums[i-1]!=13))])
  
print(sum13([1, 2, 13, 2, 1, 13])) # 4
print(sum13([1, 2, 2, 1, 13])) # 6

# %% [markdown]
# ---

# %% [markdown]
# ## Sum 67
#
# Return the sum of numbers in a list, but skip any section of numbers starting with 6 and ending with 7.

# %%
def sum67(nums):
    sum_ = 0
    i = 0

    while i != len(nums):
        if nums[i]!=6:
            sum_+=nums[i]
            i+=1
        else:
            i+=1
            while nums[i]!=7:
                i+=1
            i+=1

    return sum_
      
print(sum67([1, 2, 2]))
print(sum67([1, 2, 2, 6, 99, 99, 7]))
print(sum67([1, 1, 6, 7, 2]))

# %% [markdown]
# ---

# %% [markdown]
# ## Round Sum
#
# Round each number to the nearest 10, then return the sum.
# - Rightmost digit ≥ 5 → round up to next multiple of 10
# - Rightmost digit < 5 → round down to previous multiple of 10

# %%
def round_sum(a, b, c):
    return round10(a)+round10(b)+round10(c)
    # return 1
  
# rightmost digit is 5 or more -> round to next multiple of 10 (15->20)
# rightmost digit is less than 5 -> round to previous multiple of 10 (14->10)
# return sum

def round10(num):
    last_digit = int(str(num)[-1])
#   if str(num)[-1] < 5:
#     return num-int(str(num)[-1])
#   else:
#     return num+(10-int(str(num)[-1]))
    if last_digit < 5:
        return num - last_digit
    else:
        return num


# print(round_sum(16, 17, 18))
print(round_sum(12, 13, 14))
# print(round_sum(6, 4, 4))

# %% [markdown]
# ---

# %% [markdown]
# ## Make Bricks

# %% [markdown]
# `y = (goal - small) / 5.0` is the **minimum number of big bricks needed** if you were to use *all* your small bricks first. Three cases follow:
#
# 1. **`y` is a whole number, 0 ≤ y ≤ big** — exact fit. Use all smalls + exactly `y` bigs.
# 2. **`y > big`** — even burning all your smalls, you still need more bigs than you have. Impossible.
# 3. **Otherwise** — you have more than enough bigs, so use `ceil(y)` of them, then check if the leftover gap fits within your small supply.
#
# It works, but it's roundabout. You're approaching it from "how many bigs do I *need*?" when it's cleaner to ask "how many bigs *can* I use?"
#
# ---
#
# Use the maximum big bricks possible without overshooting, then fill the rest with smalls:
#
# ```python
# def make_bricks(small, big, goal):
#     big_used = min(big, goal // 5)   # don't use more bigs than fit
#     return (goal - big_used * 5) <= small
# ```
#
# The key insight you were missing: **greedily use as many big bricks as the goal allows**, then the problem reduces to a single comparison. Your original solution was working around the problem rather than through it.

# %%
import math

def make_bricks(small, big, goal):
    # Find the value of y for given small
    y = (goal - small)/5

    # if perfectly divisible, return 
    if y.is_integer() and 0 <= y <= big: # if y == int(y):
        return True
    elif y > big:
        return False
    else: 
        x = goal - 5*(math.ceil(y))
        return 0 <= x <= small
  
print(make_bricks(3, 1, 8))
print(make_bricks(3, 1, 9))
print(make_bricks(3, 2, 10))

# %%
print(make_bricks(6, 0, 11))
print(make_bricks(7,1,13))
print(make_bricks(40,1,46))
print(make_bricks(40,2,52))
print(make_bricks(22,2,33))

# %% [markdown]
# ---

# %% [markdown]
# ## Second Lowest Scores

# %%
records = [['Harry', 37.21], ['Berry', 37.21], ['Tina', 37.2], ['Akriti', 41], ['Harsh', 39]]
records.sort(key= lambda x: x[1])
records = list(filter(lambda x: x[1]!=records[0][1], records))
records = list(filter(lambda x: x[1]==records[0][1], records))
records.sort(key= lambda x: x[0])
print(records)

# %% [markdown]
# ---

# %% [markdown]
# ## Regex: Starts with Digit
#
# Match strings that start with a digit followed by one or more non-digit characters.

# %%
import re
strings = ["12ABC","AVS", "WF3FE", "1fe"]

for s in strings:
    result = re.search(r"^[\d][^\d]+", s)
    print(result)

# %% [markdown]
# ---

# %% [markdown]
# ## Replace Character in String
#
# Since strings are immutable in Python, you can't do `string[i] = 'x'`. Here are 5 ways to replace a character at a specific index.

# %% [markdown]
# **Approach 1**: Slicing — build a new string around the target index

# %%
string = "abracadabra"
i = 5
string = string[:i] + 'k' + string[i+1:]
print(string)  # abrackdabra

# %% [markdown]
# **Approach 2**: Convert to list, replace, rejoin

# %%
string = "abracadabra"
chars = list(string)
chars[5] = 'k'
string = ''.join(chars)
print(string)  # abrackdabra

# %% [markdown]
# **Approach 3**: `str.replace()` — replaces by *value*, not index
#
# > Caveat: risky if the character appears multiple times and you need positional precision. The `1` limits to the first occurrence.

# %%
string = "abracadabra"
string = string.replace(string[5], 'k', 1)
print(string)  # abrackdabra

# %% [markdown]
# **Approach 4**: `bytearray`
#
# A `bytearray` is a **mutable** sequence of integers (0–255), where each integer represents one byte. Since it's mutable, you can do `b[5] = ord('k')` — direct index assignment, which strings don't allow.
#
# The workflow: convert the string to bytes (`bytearray(string, 'utf-8')`), mutate the byte at the desired index, then decode back to a string (`b.decode('utf-8')`).
#
# The limitation: this operates at the **byte** level, not the character level. For pure ASCII that's fine (1 byte = 1 char), but for multi-byte Unicode characters (e.g., emojis, accented letters), byte index ≠ character index — so this approach would corrupt the string.

# %%
string = "abracadabra"
b = bytearray(string, 'utf-8')
b[5] = ord('k')
string = b.decode('utf-8')
print(string)  # abrackdabra

# %% [markdown]
# **Approach 5**: `io.StringIO`
#
# `io.StringIO` creates an **in-memory text stream** — essentially a file-like object backed by a string instead of a file on disk. It supports `seek()` to jump to a position and `write()` to overwrite characters at that position, then `getvalue()` to extract the final string.
#
# For a single replacement this is overkill (slicing is simpler and faster). But if you need to make **many positional edits** to a large string, `StringIO` avoids the O(n) cost of creating a new string each time — you write into the buffer repeatedly, then extract once at the end.

# %%
import io

string = "abracadabra"
buf = io.StringIO(string)
buf.seek(5)
buf.write('k')
string = buf.getvalue()
print(string)  # abrackdabra
